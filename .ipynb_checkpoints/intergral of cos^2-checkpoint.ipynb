# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy.integrate as si
import numpy.linalg as npla
import pandas as pd
from scipy.sparse.csc import csc_matrix

# %%
x=np.linspace(-np.pi,np.pi,100)
y=np.linspace(-np.pi,np.pi,100)
x,y=np.meshgrid(x,y)
isteps=len(x)
jsteps=len(y)

z=np.cos(x+y)#**2
#print(z)

plt.contour(x,y,z)
plt.show()

print(x[0])
print(z)
print(x.shape)
print(y.shape)
print(z.shape)

Int=np.zeros((isteps,isteps))
for i in range(isteps):
    Int[i,i]=si.simps(z[i,:i+1],x[i,:i+1])
   # Int[i,i]=si.simps(Int[i,:i+1],x[i,:i+1])
    #Int[i]=si.simps(Int[:i+1],x[i,:i+1])
#Int2=np.zeros(isteps)
#for i in range(isteps):
#    Int2[i]=si.simps(Int[:i+1],x[i,:i+1])
print(np.shape(Int))
print(Int)
#print(np.shape(Int2))
#print(Int2)
#Int,Int2=np.meshgrid(Int,Int2)
print(Int.shape)
plt.plot(Int)
plt.show()

plt.contour(x,y,Int)
plt.show()
# Out:
# [-3.14159265 -3.07812614 -3.01465962 -2.9511931  -2.88772658 -2.82426006
#  -2.76079354 -2.69732703 -2.63386051 -2.57039399 -2.50692747 -2.44346095
#  -2.37999443 -2.31652792 -2.2530614  -2.18959488 -2.12612836 -2.06266184
#  -1.99919533 -1.93572881 -1.87226229 -1.80879577 -1.74532925 -1.68186273
#  -1.61839622 -1.5549297  -1.49146318 -1.42799666 -1.36453014 -1.30106362
#  -1.23759711 -1.17413059 -1.11066407 -1.04719755 -0.98373103 -0.92026451
#  -0.856798   -0.79333148 -0.72986496 -0.66639844 -0.60293192 -0.53946541
#  -0.47599889 -0.41253237 -0.34906585 -0.28559933 -0.22213281 -0.1586663
#  -0.09519978 -0.03173326  0.03173326  0.09519978  0.1586663   0.22213281
#   0.28559933  0.34906585  0.41253237  0.47599889  0.53946541  0.60293192
#   0.66639844  0.72986496  0.79333148  0.856798    0.92026451  0.98373103
#   1.04719755  1.11066407  1.17413059  1.23759711  1.30106362  1.36453014
#   1.42799666  1.49146318  1.5549297   1.61839622  1.68186273  1.74532925
# ...

# %%
x=np.linspace(-np.pi,np.pi,10000)
isteps=len(x)
dx=max(x)/isteps
y=np.cos(x)**2
print(y)
#simps
Int=np.zeros(isteps)
for i in range(isteps):
    Int[i]=si.simps(y[:i+1],x[:i+1])
plt.plot(x,Int)
plt.show()


#reinmann
def integral(y):
    Integral=0.
    for i in range(isteps-1):
        Integral=Integral+2*y[i]*dx
    return Integral

for i in range(isteps-1):
    Int[i]=integral(y)
plt.plot(x,Int)
plt.show()
print(Int)
# Out:
# [1.         0.99999961 0.99999842 ... 0.99999842 0.99999961 1.        ]
# [3.14127849 3.14127849 3.14127849 ... 3.14127849 3.14127849 3.14159265]
